# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
model.info()
# Out:
# YOLOv8n summary: 225 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# (225, 3157200, 0, 8.8575488)

# %%
results=model(source="video2.mp4",show=True,conf=0.5,save=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/411) C:\Users\AS\video2.mp4: 640x384 (no detections), 509.3ms
# video 1/1 (frame 2/411) C:\Users\AS\video2.mp4: 640x384 (no detections), 426.2ms
# video 1/1 (frame 3/411) C:\Users\AS\video2.mp4: 640x384 (no detections), 275.9ms
# video 1/1 (frame 4/411) C:\Users\AS\video2.mp4: 640x384 (no detections), 197.0ms
# video 1/1 (frame 5/411) C:\Users\AS\video2.mp4: 640x384 (no detections), 305.9ms
# ...
